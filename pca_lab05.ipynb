# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
#dataset creation
data ={
    "week" : [1,2,3,4],
    "sales":[1.2,1.8.2.6.3.2,3.8]
}
#before in that data only created as a dictionary now the dictionary is converted into an table format(Data frame)
df=pd.DataFrame(data)
#select which is input and output x is input and y is output
x=d[["week"]]
y=df["sales"]
